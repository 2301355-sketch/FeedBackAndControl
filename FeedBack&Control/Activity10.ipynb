# %%
# !pip install openai
# !pip show openai


from openai import OpenAI

client = OpenAI(
    base_url="http://127.0.0.1:1234/v1",
    api_key="lm-studio"
)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in c:\users\man\appdata\roaming\python\python314\site-packages (2.32.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\man\appdata\roaming\python\python314\site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\man\appdata\roaming\python\python314\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\man\appdata\roaming\python\python314\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\man\appdata\roaming\python\python314\site-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\man\appdata\roaming\python\python314\site-packages (from openai) (2.13.2)
# Requirement already satisfied: sniffio in c:\users\man\appdata\roaming\python\python314\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\man\appdata\roaming\python\python314\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\man\appdata\roaming\python\python314\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\man\appdata\roaming\python\python314\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\man\appdata\roaming\python\python314\site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\man\appdata\roaming\python\python314\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\man\appdata\roaming\python\python314\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\man\appdata\roaming\python\python314\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in c:\users\man\appdata\roaming\python\python314\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\man\appdata\roaming\python\python314\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\man\appdata\roaming\python\python314\site-packages (from tqdm>4->openai) (0.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Python314\python.exe -m pip install --upgrade pip
# Name: openai
# Version: 2.32.0
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: C:\Users\man\AppData\Roaming\Python\Python314\site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:

# %%
import keyboard
from langchain_community.chat_message_histories import ChatMessageHistory

# Initialize the history object to keep track of the discussion
history = ChatMessageHistory()

# %%
while True:
    query = input("\nUser (Enter to Continue || Type 'exit' or press ESC to exit): ")

    # Check for the ESC character (\x1b) OR a simple 'exit' command
    if keyboard.is_pressed('Esc') or query.lower() == 'exit':
        print("\nExiting...")
        print("Program Finished.")
        break
    print("User Input: " + query)
    print('- ' * 50)
    if not query.strip():
        continue
    # Add user message to LangChain history
    history.add_user_message(query)

    # Convert LangChain 'human/ai' roles to OpenAI 'user/assistant' roles
    messages_with_history = []
    for m in history.messages:
        # LangChain uses 'human' for user and 'ai' for assistant
        role = "user" if m.type == "human" else "assistant"
        messages_with_history.append({"role": role, "content": m.content})

    # Ensured stream is called only once with the correctly mapped history
    stream = client.chat.completions.create(
        model="google/gemma-4-e4b",
        messages=messages_with_history,
        stream=True
    )
    full_ai_response = ""       # Temporary variable to capture the full AI response for memory

    for chunk in stream:
        if chunk.choices[0].delta.content:
            content = chunk.choices[0].delta.content
            print(content, end="", flush=True)
            full_ai_response += content     # Build the string as it streams

    # Save the AI response back to LangChain history
    history.add_ai_message(full_ai_response)
    print('\n ')     # Print a newline for readability
    print('=' * 100)
    print(' ')
# Out:
# User Input: man
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# "Man" is a wonderfully broad word that can be interpreted in many ways—scientifically, grammatically, conceptually, or culturally.
#
# To give you the most relevant information, I will break down the various meanings and contexts of "man."
#
# ***
#
# ### 🧑‍🔬 Scientific/Biological Definition
# A **man** refers to an adult human male belonging to the species *Homo sapiens*. Biologically, it is defined by a specific range of chromosomes (XY), hormonal profile, skeletal structure, and physical characteristics that distinguish the sex.
#
# ### 📖 Linguistic & Grammatical Meanings
#
# 1.  **Noun (Person):** A male human being.
#     * *(Example: "The man across the street.")*
# 2.  **Pronoun:** Used to refer back to a male person previously mentioned.
#     * *(Example: "He told me that **man** was lying.")*
# 3.  **Conceptual Noun (Manhood):** The state or condition of being an adult male; maturity and masculinity.
#
# ### 🌎 Conceptual & Sociological Meanings
#
# When used conceptually, the word takes on deeper meaning related to roles, humanity, and civilization:
#
# *   **Humanity:** Often used in older English usage (e.g., "the rights of man"), it can refer to mankind as a whole—all humans regardless of gender or race.
# *   **Masculinity:** Refers to the social, cultural, and behavioral expectations associated with being male ("manhood"). These roles are highly variable across cultures and time periods.
# *   **Agency:** Conceptually, "man" can represent free will or independent action (e.g., "Man has proven his resilience.").
#
# ### 🎭 Cultural & Historical Contexts
# The concept of the "man" is central to mythology, religion, and philosophy:
#
# *   **Mythology:** Figures like Adam, Prometheus, and Hercules embody the archetypal man—the creator, the rebel, or the hero.
# *   **Philosophy:** Philosophers have debated the nature of man (anthropology) since antiquity, asking questions like: *What defines human consciousness? Are we inherently good or bad?*
#
# ***
#
# ### ✨ How can I help you further?
#
# Since "man" can mean so many things, could you tell me which context you are interested in? For example, are you looking for:
#
# 1.  **A definition of masculinity?** (Sociology)
# 2.  **Information about the history of humanity?** (Anthropology)
# 3.  **The grammatical function of the word "man"?** (Grammar)
# 4.  **Something else entirely?**
#
# ====================================================================================================
#
#
# Exiting...
# Program Finished.
